# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
df = pd.read_csv(url, sep='\t')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75

# %%
# print the name of all columns 
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# print total recoed and type  of variables
df.info(), df.shape, df.shape[0],df.shape[1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB
# (None, (4622, 5), 4622, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# whixh was the mmost ordered item ? and how many item were ordered ?
c = df.groupby('item_name')

# %%
c = c.sum()
c
# Out:
#                                        order_id  quantity  item_price
# item_name
# 6 Pack Soft Drink                         52322        55      356.95
# Barbacoa Bowl                             53972        66      672.36
# Barbacoa Burrito                          74718        91      894.75
# Barbacoa Crispy Tacos                      5613        12      120.21
# Barbacoa Salad Bowl                        9708        10      106.40
# Barbacoa Soft Tacos                       18725        25      250.46
# Bottled Water                            175944       211      302.56
# Bowl                                        472         4       29.60
# Burrito                                    1550         6       44.40
# Canned Soda                               76396       126      137.34
# Canned Soft Drink                        304753       351      438.75
# Carnitas Bowl                             62742        71      736.71
# ...

# %%
c = c.sort_values(['quantity'], ascending=False)
c
# Out:
#                                        order_id  quantity  item_price
# item_name
# Chicken Bowl                             713926       761     7342.73
# Chicken Burrito                          497303       591     5575.82
# Chips and Guacamole                      449959       506     2201.04
# Steak Burrito                            328437       386     3851.43
# Canned Soft Drink                        304753       351      438.75
# Chips                                    208004       230      494.34
# Steak Bowl                               193752       221     2260.19
# Bottled Water                            175944       211      302.56
# Chips and Fresh Tomato Salsa             100419       130      361.36
# Canned Soda                               76396       126      137.34
# Chicken Salad Bowl                       117104       123     1228.75
# Chicken Soft Tacos                        98395       120     1108.09
# ...

# %%
c.head()
# Out:
#                      order_id  quantity  item_price
# item_name
# Chicken Bowl           713926       761     7342.73
# Chicken Burrito        497303       591     5575.82
# Chips and Guacamole    449959       506     2201.04
# Steak Burrito          328437       386     3851.43
# Canned Soft Drink      304753       351      438.75

# %%
c = df.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity  item_price
# item_name
# Chicken Bowl    713926       761     7342.73

# %%
# what was the most ordered item in the choice_description column 
c = df.groupby('choice_description').sum()
c = c.sort_values(['quantity'],ascending=False)
c.head(1)
# Out:
#                     order_id  quantity  item_price
# choice_description
# [Diet Coke]           123455       159      326.71

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
dollar = lambda x: float(x[1:-1])
df.item_price = df.item_price.apply(dollar)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-0ecdd0ea973f> in <module>
#       1 dollar = lambda x: float(x[1:-1])
# ----> 2 df.item_price = df.item_price.apply(dollar)
#
# c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-54-0ecdd0ea973f> in <lambda>(x)
# ----> 1 dollar = lambda x: float(x[1:-1])
#       2 df.item_price = df.item_price.apply(dollar)
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# #How much was the revenue for the period in the dataset?

# %%
df.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#    item_price
# 0        2.39
# 1        3.39

# %%
revenue = (df['quantity']* df['item_price']).sum()
revenue
# Out:
# 39237.02

# %%
print('Revenue was : $' +str(np.round(revenue,2)))
# Out:
# Revenue was : $39237.02

# %% [markdown]
# #print a data frame with only two columns item_name and item_price

# %%
data = df[['item_name','item_price']]
data
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
# delet the duplicate data in item name and quantity 
filtered = df.drop_duplicates(['item_name', 'quantity'])
filtered.shape,data.shape
# Out:
# ((103, 5), (4622, 2))

# %%
# selct any product with quantity equal to 1 
one_prod = filtered[filtered.quantity == 1]
one_prod
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 21          11         1                       Barbacoa Burrito
# 27          14         1                       Carnitas Burrito
# ...

# %%
price_per_item = one_prod[['item_name', 'item_price']]
price_per_item
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 5                              Chicken Bowl       10.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 16                          Chicken Burrito        8.49
# 21                         Barbacoa Burrito        8.99
# 27                         Carnitas Burrito        8.99
# 28                              Canned Soda        1.09
# 33                            Carnitas Bowl        8.99
# ...

# %%
price_per_item.sort_values(by = 'item_price', ascending=False)
# Out:
#                                   item_name  item_price
# 606                        Steak Salad Bowl       11.89
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 39                            Barbacoa Bowl       11.75
# 738                       Veggie Soft Tacos       11.25
# 186                       Veggie Salad Bowl       11.25
# 62                              Veggie Bowl       11.25
# 57                           Veggie Burrito       11.25
# 250                           Chicken Salad       10.98
# 5                              Chicken Bowl       10.98
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 56                      Barbacoa Soft Tacos        9.25
# ...

# %%
#What was the quantity of the most expensive item ordered?


df.sort_values(by='item_price', ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
#How many times were a Veggie Salad Bowl ordered?
df[df.item_name == 'Veggie Salad Bow']
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %%
df[df.item_name == "Veggie Salad Bowl"]
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...

# %%
url = 'https://github.com/justmarkham/DAT8/blob/master/data/beer.txt'

# %%
df = pd.read_table('beer.txt', delim_whitespace=True)
df
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
df.shape
# Out:
# (20, 5)

# %%
df.columns
# Out:
# Index(['name', 'calories', 'sodium', 'alcohol', 'cost'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
df.describe()
# Out:
#          calories     sodium    alcohol       cost
# count   20.000000  20.000000  20.000000  20.000000
# mean   132.550000  14.950000   4.240000   0.494500
# std     30.283702   6.581273   1.087924   0.144858
# min     68.000000   6.000000   0.900000   0.280000
# 25%    110.250000   9.500000   4.175000   0.427500
# 50%    144.000000  15.000000   4.600000   0.435000
# 75%    150.250000  19.000000   4.900000   0.485000
# max    175.000000  27.000000   5.500000   0.790000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
# name        20 non-null object
# calories    20 non-null int64
# sodium      20 non-null int64
# alcohol     20 non-null float64
# cost        20 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 928.0+ bytes

# %%
df.dtypes
# Out:
# name         object
# calories      int64
# sodium        int64
# alcohol     float64
# cost        float64
# dtype: object

# %%
dd = df.dtypes=='object'
dd[0]
# Out:
# True

# %%
df.groupby('name').sum()
# Out:
#                       calories  sodium  alcohol  cost
# name
# Augsberger                 175      24      5.5  0.40
# Becks                      150      19      4.7  0.76
# Budweiser                  144      15      4.7  0.43
# Budweiser_Light            113       8      3.7  0.40
# Coors                      140      18      4.6  0.44
# Coors_Light                102      15      4.1  0.46
# Hamms                      139      19      4.4  0.43
# Heilemans_Old_Style        144      24      4.9  0.43
# Heineken                   152      11      5.0  0.77
# Kirin                      149       6      5.0  0.79
# Kronenbourg                170       7      5.2  0.73
# Lowenbrau                  157      15      0.9  0.48
# Michelob_Light             135      11      4.2  0.50
# Miller_Lite                 99      10      4.3  0.43
# Old_Milwaukee              145      23      4.6  0.28
# Olympia_Goled_Light         72       6      2.9  0.46
# ...

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %%
crime = pd.read_csv(url)

# %%
crime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
crime.shape
# Out:
# (55, 12)

# %%
crime.isnull().sum()
# Out:
# Year                  0
# Population            0
# Total                 0
# Violent               0
# Property              0
# Murder                0
# Forcible_Rape         0
# Robbery               0
# Aggravated_assault    0
# Burglary              0
# Larceny_Theft         0
# Vehicle_Theft         0
# dtype: int64

# %%
# convert the time of the column yaer to datetime64

crime.Year = pd.to_datetime(crime.Year, format='%Y')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
# Year                  55 non-null datetime64[ns]
# Population            55 non-null int64
# Total                 55 non-null int64
# Violent               55 non-null int64
# Property              55 non-null int64
# Murder                55 non-null int64
# Forcible_Rape         55 non-null int64
# Robbery               55 non-null int64
# Aggravated_assault    55 non-null int64
# Burglary              55 non-null int64
# Larceny_Theft         55 non-null int64
# Vehicle_Theft         55 non-null int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
crime.head(2)
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000

# %%
#set the year column as the index of the dataframes 
crime = crime.set_index('Year', drop=True)
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
# group the yeart by decades and sum the value 
crimes = crime.resample('10AS').sum()
crimes
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
#uses resample to get the max  value only for the 'population' column
population = crime['Population'].resample('10AS').max()
population
# Out:
# Year
# 1960-01-01    201385000
# 1970-01-01    220099000
# 1980-01-01    248239000
# 1990-01-01    272690813
# 2000-01-01    307006550
# 2010-01-01    318857056
# Freq: 10AS-JAN, Name: Population, dtype: int64

# %%
crimes['Population'] = population

# %%
crimes
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
# 1990-01-01   272690813  136582146  17527048  119053499  211664         998827
# 2000-01-01   307006550  115012044  13968056  100944369  163068         922499
# 2010-01-01   318857056   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
crime.head()
# Out:
#              Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01  201385000.0  3384200   288460   3095700    9110          17190
# 1961-01-01          NaN  3488000   289390   3198600    8740          17220
# 1962-01-01          NaN  3752200   301510   3450700    8530          17550
# 1963-01-01          NaN  4109500   316970   3792500    8640          17650
# 1964-01-01          NaN  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
fd = crimes

# %%
fd
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
# 1990-01-01   272690813  136582146  17527048  119053499  211664         998827
# 2000-01-01   307006550  115012044  13968056  100944369  163068         922499
# 2010-01-01   318857056   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
df =fd

# %%
df.shape
# Out:
# (6, 11)

# %%
df.head()
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
# 1990-01-01   272690813  136582146  17527048  119053499  211664         998827
# 2000-01-01   307006550  115012044  13968056  100944369  163068         922499
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
#
#             Vehicle_Theft
# Year
# 1960-01-01        5292100
# 1970-01-01        9739900
# ...

# %%
df.iloc[:3]
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
#
#             Vehicle_Theft
# Year
# 1960-01-01        5292100
# 1970-01-01        9739900
# 1980-01-01       11935411

# %%
# select just the 'Murder' and 'Robbery' coluns for the datafraem df and 
df.loc[:,['Murder', 'Robbery']]
# Out:
#             Murder  Robbery
# Year
# 1960-01-01  106180  1633510
# 1970-01-01  192230  4159020
# 1980-01-01  206439  5383109
# 1990-01-01  211664  5748930
# 2000-01-01  163068  4230366
# 2010-01-01   72867  1749809

# %%
df[['Murder','Robbery']].head()
# Out:
#             Murder  Robbery
# Year
# 1960-01-01  106180  1633510
# 1970-01-01  192230  4159020
# 1980-01-01  206439  5383109
# 1990-01-01  211664  5748930
# 2000-01-01  163068  4230366

# %%
#select the data in rows [3,4,8] and columns ['Murder', 'Robbery']
df.loc[df.index[[3,4,5]], ['Murder','Robbery']]
# Out:
#             Murder  Robbery
# Year
# 1990-01-01  211664  5748930
# 2000-01-01  163068  4230366
# 2010-01-01   72867  1749809

# %%
# select the row where the number of murder in freater tha 24k

# %%
df[df['Murder']>24000]
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
# 1990-01-01   272690813  136582146  17527048  119053499  211664         998827
# 2000-01-01   307006550  115012044  13968056  100944369  163068         922499
# 2010-01-01   318857056   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
df[df['Murder'].between(20000,24000)]
# Out:
# Empty DataFrame
# Columns: [Population, Total, Violent, Property, Murder, Forcible_Rape, Robbery, Aggravated_assault, Burglary, Larceny_Theft, Vehicle_Theft]
# Index: []

# %%
# clculate the mean murder for each different year in df 
df.groupby('Year')['Murder'].mean()
# Out:
# Year
# 1960-01-01    106180
# 1970-01-01    192230
# 1980-01-01    206439
# 1990-01-01    211664
# 2000-01-01    163068
# 2010-01-01     72867
# Freq: 10AS-JAN, Name: Murder, dtype: int64

# %%
#Sort df first by the values in the 'Murder' in decending order,
#then by the value in the 'Violent' column in ascending order.

# %%
df.sort_values(by=['Murder', 'Violent'], ascending=[False, True])
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1990-01-01   272690813  136582146  17527048  119053499  211664         998827
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 2000-01-01   307006550  115012044  13968056  100944369  163068         922499
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 2010-01-01   318857056   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1990-01-01  5748930            10568963  26750015       77679366
# 1980-01-01  5383109             7619130  33073494       72040253
# 1970-01-01  4159020             4702120  28486000       53157800
# 2000-01-01  4230366             8652124  21565176       67970291
# 1960-01-01  1633510             2158520  13321100       26547700
# ...

# %%
url = "https://github.com/vincentarelbundock/Rdatasets/blob/master/datasets.csv"

# %%
df = pd.read_csv('datasets.csv')
df.head()
# Out:
#   Package        Item                                         Title  Rows  \
# 0    boot        acme                        Monthly Excess Returns    60
# 1    boot        aids  Delay in AIDS Reporting in England and Wales   570
# 2    boot   aircondit        Failures of Air-conditioning Equipment    12
# 3    boot  aircondit7        Failures of Air-conditioning Equipment    24
# 4    boot        amis                Car Speeding and Warning Signs  8437
#
#    Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0     3         0            1         0          0          2
# 1     6         1            0         0          0          6
# 2     1         0            0         0          0          1
# 3     1         0            0         0          0          1
# 4     4         1            0         0          0          4
#
#                                                  CSV  \
# 0  https://vincentarelbundock.github.io/Rdatasets...
# ...

# %%
df.head(2)
# Out:
#   Package  Item                                         Title  Rows  Cols  \
# 0    boot  acme                        Monthly Excess Returns    60     3
# 1    boot  aids  Delay in AIDS Reporting in England and Wales   570     6
#
#    n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0         0            1         0          0          2
# 1         1            0         0          0          6
#
#                                                  CSV  \
# 0  https://vincentarelbundock.github.io/Rdatasets...
# 1  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                  Doc
# 0  https://vincentarelbundock.github.io/Rdatasets...
# 1  https://vincentarelbundock.github.io/Rdatasets...
